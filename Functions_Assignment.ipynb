# %% [markdown]
# #Theory Questions:

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
# - The difference between a funtion and a method in python.
#
#  A function is something you define using def and you can call it on its own. It’s not tied to any object.
#
#  A method is like a function, but it’s part of an object (usually an object of a class). So, you call it on that object.
#
# 2. Explain the concept of function arguments and parameters in Python.
# - In Python, when we create a function, we can make it accept some inputs so it can do different things based on what we give it. These inputs are called parameters and arguments.
#
#  Here is the difference.
#
#  Parameters are the names you write when defining the function.
#
#  Arguments are the actual values you pass when calling the function.
#
# 3. What are the different ways to define and call a function in Python?
# - In Python, a function is a block of reusable code that performs a specific task. Functions help make programs easier to read, manage, and reuse.
#
#  Defining a Function - We use the def keyword followed by the function name and parentheses. Here are the different ways to define a function.
#
#  Calling a Function - After defining a function, we can call it by writing its name followed by parentheses. We provide arguments inside the parentheses if needed.
#
# 4. What is the purpose of the 'return' statement in a Python function?
# - The return statement in Python is used to send a value back from a function to the place where it was called. It's like the output of the function.
#
#  When a function uses return, it gives back a result that we can store in a variable, print, or use in other operations.
#
# 5. What are iterators in Python and how do they differ from iterables?
# - In Python, iterators and iterables are related but not the same. They both help us loop over data, like in a for loop, but they have different roles.
#
#  An iterable is anything you can loop over using a for loop. It doesn’t give you items directly — instead, it knows how to create an iterator.
#
#  An iterator is an object that remembers where it is during iteration and gives you the next item when you ask for it. You get an iterator from an iterable using the iter() function.
#
# 6. Explain the concept of generators in Python and how they are defined.
# - In Python, generators are a simple and memory-efficient way to create iterators. Instead of returning all the values at once (like a list), a generator yields one value at a time — only when you need it.
# You define a generator like a normal function, but use yield instead of return.
#
# 7. What are the advantages of using generators over regular functions?
# - Generators in Python are like normal functions, but they use yield instead of return. They are useful when we want to return a series of values one at a time, instead of all at once.
#
#  Here are some advantages of using generators over regular functions:
#
#  Saves Memory
#
#  Faster Start Time
#
#  Lazy Evaluation
#
#  Can Handle Infinite Data
#
#  Cleaner and Simpler Code
#
#  Works Well with Loops
#
# 8. What is a lambda function in Python and when is it typically used?
# - A lambda function in Python is a small, anonymous (no name) function. It is used when we need a simple function for a short period of time and don’t want to define it using the regular def keyword.
#
# 9. Explain the purpose and usage of the `map()` function in Python.
# - The map() function in Python is used to apply a function to every item in a list (or any iterable) and return a new object with the results. It’s a quick way to transform all elements without writing a loop.
#
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# - In Python, map(), reduce(), and filter() are built-in functions that help us work with data in lists or other collections. They are used to process each item in a smart and simple way, but they each do different things.
#
# 11.  Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
# - ![WhatsApp Image 2025-05-20 at 1.38.03 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Practical Questions:

# %%
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
'''
def sum_of_even_numbers(numbers):
    """
    Returns the sum of all even numbers in the given list.

    Parameters:
    numbers (list): A list of integers.

    Returns:
    int: Sum of even numbers in the list.
    """
    return sum(num for num in numbers if num % 2 == 0)

# Example usage:
example_list = [1, 2, 3, 4, 5, 6]
result = sum_of_even_numbers(example_list)
print("Sum of even numbers:", result)

'''
# Out:
# '\ndef sum_of_even_numbers(numbers):\n    """\n    Returns the sum of all even numbers in the given list.\n\n    Parameters:\n    numbers (list): A list of integers.\n\n    Returns:\n    int: Sum of even numbers in the list.\n    """\n    return sum(num for num in numbers if num % 2 == 0)\n\n# Example usage:\nexample_list = [1, 2, 3, 4, 5, 6]\nresult = sum_of_even_numbers(example_list)\nprint("Sum of even numbers:", result)\n\n'

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string.
'''
def reverse_string(text):
    reversed_text = ''
    for char in text:
        reversed_text = char + reversed_text
    return reversed_text

# Example usage:
user_input = input("Enter a string: ")
print("Reversed string:", reverse_string(user_input))
'''
# Out:
# '\ndef reverse_string(text):\n    reversed_text = \'\'\n    for char in text:\n        reversed_text = char + reversed_text\n    return reversed_text\n\n# Example usage:\nuser_input = input("Enter a string: ")\nprint("Reversed string:", reverse_string(user_input))\n\n'

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
'''
def square_numbers(numbers):
    squares = []
    for num in numbers:
        squares.append(num * num)
    return squares

# Example usage:
nums = [1, 2, 3, 4, 5]
print("Squares:", square_numbers(nums))
'''
# Out:
# '\ndef square_numbers(numbers):\n    squares = []\n    for num in numbers:\n        squares.append(num * num)\n    return squares\n\n# Example usage:\nnums = [1, 2, 3, 4, 5]\nprint("Squares:", square_numbers(nums))\n\n'

# %%
#4. Write a Python function that checks if a given number is prime or not from 1 to 200.
'''
number = int(input("Enter a number between 1 and 200: "))
if 1 <= number <= 200:
    if is_prime(number):
        print(number, "is a prime number.")
    else:
        print(number, "is not a prime number.")
else:
    print("Please enter a number within the range 1 to 200.")
'''
# Out:
# '\nnumber = int(input("Enter a number between 1 and 200: "))\nif 1 <= number <= 200:\n    if is_prime(number):\n        print(number, "is a prime number.")\n    else:\n        print(number, "is not a prime number.")\nelse:\n    print("Please enter a number within the range 1 to 200.")\n'

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
'''
class Fibonacci:
    def __init__(self, n):
        self.n, self.a, self.b, self.count = n, 0, 1, 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return 0
        self.a, self.b = self.b, self.a + self.b
        self.count += 1
        return self.a

# Example usage:
for num in Fibonacci(10):
    print(num)
'''
# Out:
# '\nclass Fibonacci:\n    def __init__(self, n):\n        self.n, self.a, self.b, self.count = n, 0, 1, 0\n\n    def __iter__(self):\n        return self\n\n    def __next__(self):\n        if self.count >= self.n:\n            raise StopIteration\n        if self.count == 0:\n            self.count += 1\n            return 0\n        self.a, self.b = self.b, self.a + self.b\n        self.count += 1\n        return self.a\n\n# Example usage:\nfor num in Fibonacci(10):\n    print(num)\n'

# %%
#6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
'''
def powers_of_two(n):
    for i in range(n + 1):
        yield 2 ** i

# Example usage:
for val in powers_of_two(5):
    print(val)
'''
# Out:
# '\ndef powers_of_two(n):\n    for i in range(n + 1):\n        yield 2 ** i\n\n# Example usage:\nfor val in powers_of_two(5):\n    print(val)\n'

# %%
#7. Implement a generator function that reads a file line by line and yields each line as a string.
'''
def read_file_lines(filename):
    with open(filename, 'r') as f:
        for line in f:
            yield line

# Example usage:
for line in read_file_lines('example.txt'):
    print(line, end='')
'''
# Out:
# "\ndef read_file_lines(filename):\n    with open(filename, 'r') as f:\n        for line in f:\n            yield line\n\n# Example usage:\nfor line in read_file_lines('example.txt'):\n    print(line, end='')\n"

# %%
#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
'''
data = [(1, 3), (4, 1), (5, 2)]
sorted_data = sorted(data, key=lambda x: x[1])
print(sorted_data)
'''
# Out:
# '\ndata = [(1, 3), (4, 1), (5, 2)]\nsorted_data = sorted(data, key=lambda x: x[1])\nprint(sorted_data)\n'

# %%
#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
'''
celsius = [0, 20, 37, 100]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))
print(fahrenheit)
'''
# Out:
# '\ncelsius = [0, 20, 37, 100]\nfahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))\nprint(fahrenheit)\n'

# %%
#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
'''
text = "Hello, world!"
vowels = "aeiouAEIOU"
result = ''.join(filter(lambda ch: ch not in vowels, text))
print(result)
'''
# Out:
# '\ntext = "Hello, world!"\nvowels = "aeiouAEIOU"\nresult = \'\'.join(filter(lambda ch: ch not in vowels, text))\nprint(result)\n'

# %%
#11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:

#Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
#product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
#order is smaller than 100,00 €.
#Write a Python program using lambda and map.
'''
book_orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99],
]

result = list(map(lambda order: (order[0], (order[2] * order[3] + 10) if (order[2] * order[3]) < 100 else (order[2] * order[3])), book_orders))

print(result)
'''
# Out:
# '\nbook_orders = [\n    [34587, "Learning Python, Mark Lutz", 4, 40.95],\n    [98762, "Programming Python, Mark Lutz", 5, 56.80],\n    [77226, "Head First Python, Paul Barry", 3, 32.95],\n    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99],\n]\n\nresult = list(map(lambda order: (order[0], (order[2] * order[3] + 10) if (order[2] * order[3]) < 100 else (order[2] * order[3])), book_orders))\n\nprint(result)\n'
